# %% [markdown]
# # Extaccion de datos
#
#
# Requisito: obtener y configurar tu `API_KEY` de kaggle para poder descargar los datasets.
#
# TODO: Agregar un drive publico para facilitar la descarga de los datasets.

# %%
from setup import set_project_root # codigo para establecer la raiz del proyecto
set_project_root()
# Out:
# Current working directory: /home/chris/Documentos/u/dataviz/Denmark-HousePrices-Analysis

# %%
import subprocess

def download_data():
    subprocess.run([
        "kaggle", "datasets", "download",
        "martinfrederiksen/danish-residential-housing-prices-1992-2024",
        "--unzip", "-p", "data/raw"
    ])

# %%
download_data()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/martinfrederiksen/danish-residential-housing-prices-1992-2024
# License(s): other
# Downloading danish-residential-housing-prices-1992-2024.zip to data/raw
# 100%|██████████| 36.2M/36.2M [00:08<00:00, 4.34MB/s]
